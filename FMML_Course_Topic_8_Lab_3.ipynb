# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavipython/FMML_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-03 15:49:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   375MB/s    in 0.2s
#
# 2023-06-03 15:49:41 (375 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22018   1311.4669v1  Symmetric binary matrices representing relatio...  stat
# 14477  cs/0102026v1  The data on 13 typologically different languag...    cs
# 36876  1508.00116v1  Developments in semantic web technologies have...    cs
# 39198   1411.7336v1  Shapes and texture image recognition usage is ...    cs
# 5904    1212.3276v3  We consider the problem of learning a non-nega...  stat
# ...             ...                                                ...   ...
# 21685   1308.1196v2  We introduce an application of the group lasso...  stat
# 24288   1307.2434v1  Remote sensing has proven to be a powerful too...    cs
# 21849   1401.2771v1  Recently, a number of mostly $\ell_1$-norm reg...  stat
# 13061   1411.0630v1  We consider active maximum a posteriori (MAP) ...  stat
# 10500   1205.0079v2  The regularization path of the Lasso can be sh...  stat
#
#                                                    title  year  \
# 22018  Nonparametric Bayes dynamic modeling of relati...  2013
# 14477  Mathematical Model of Word Length on the Basis...  2001
# 36876  Extending SROIQ with Constraint Networks and G...  2015
# 39198  Edge direction matrixes-based local binar patt...  2014
# 5904    Learning Sparse Low-Threshold Linear Classifiers  2012
# ...                                                  ...   ...
# 21685          The Group Lasso for Design of Experiments  2013
# 24288              Major Limitations of Satellite images  2013
# 21849  A variational Bayes framework for sparse adapt...  2014
# 13061  Active Inference for Binary Symmetric Hidden M...  2014
# 10500  Complexity Analysis of the Lasso Regularizatio...  2012
#
#                                                 keywords
# 22018  [symmetric, representing, relations, collected...
# 14477  [typologically, different, languages, processe...
# 36876  [developments, technologies, ontological, know...
# 39198  [recognition, essential, recognition, techniqu...
# 5904   [classifier, threshold, generalizes, disjuncti...
# ...                                                  ...
# 21685  [introduce, application, experiments, experime...
# 24288  [monitoring, perception, surroundings, unprece...
# 21849  [regularized, deterministic, algorithms, emphs...
# 13061  [posteriori, inference, estimation, remaining,...
# 10500  [regularization, piecewise, explicitly, comple...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22018    [symmetric, representing, relations, collected...
# 14477    [typologically, different, languages, processe...
# 36876    [developments, technologies, ontological, know...
# 39198    [recognition, essential, recognition, techniqu...
# 5904     [classifier, threshold, generalizes, disjuncti...
#                                ...
# 22405    [interaction, interactions, nucleotide, polymo...
# 38341    [extremely, unstructured, challenge, accompani...
# 39024    [dissimilarity, geometric, different, geometri...
# 14806    [following, principles, cognitive, concentrate...
# 9651     [stochastic, stochastic, algorithm, reformulat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8743 words.
# Out of those 4536 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ef7abb68-0294-428b-95b3-284693203e39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef7abb68-0294-428b-95b3-284693203e39")) {                    Plotly.newPlot(                        "ef7abb68-0294-428b-95b3-284693203e39",                        [{"x":["coordinates","dynamically","prediction","posterior","processes","experiments","formulation","structure","simulation","employing","tractable","automatically","flexibility","movements","collected","nonparametric","financial","illustrate","dimensional","characterizing","computational","inference","computation","relationship","relational","symmetric","continuous","performance","augmentation","theoretical","dimensionality","probability","efficient","dimension","representation","developed","application","representing","relations","processed","languages","displaced","statistical","different","mathematical","parameter","typologically","dependencies","distribution","applications","ontologies","constructs","ontological","terminating","expressiveness","constraint","information","reasoning","expressive","including","technologies","practical","algorithm","embedding","knowledge","presently","intuitive","extending","description","prominently","modelling","circumscription","developments","framework","semantics","defeasible","classifier","complementing","invariance","introduced","capabilities","uniformity","direction","occurrence","secondary","literature","simultaneously","descriptors","essential","advantages","perceptron","descriptor","invariants","benchmark","methodology","invariant","superiority","transform","techniques","relationships","collaboration","approaches","extracting","introducing","recognition","threshold","classifiers","empirical","efficiently","disjunction","convergence","minimization","generalizes","describes","intrinsic","advantage","optimizing","factorization","appealing","combinatorial","sequential","evaluated","illustrated","approximate","variational","parametric","approximation","assessment","probabilistic","deterministic","operators","strengths","alternatives","debugging","unstructured","facilitates","templates","partition","statistics","approximations","variables","phylogenetic","ensembling","averaging","explanatory","technique","continues","comparing","alignment","particular","categorical","generating","clusterings","demonstrating","clustering","conditions","sequences","suggested","dissimilarity","processing","analytically","considerable","restricted","simplified","computationally","intractable","intensive","asymptotics","posteriori","dirichlet","likelihood","ubiquitous","resources","plentiful","validation","degenerate","potential","algorithms","statistically","requiring","leverages","intelligent","interference","demonstrate","streaming","introduction","additional","surroundings","catastrophic","development","distributions","architecture","regularizer","everything","generative","continuously","incorporate","consecutive","components","reduction"],"y":[14,25,228,50,92,644,88,325,82,36,25,194,32,13,77,17,14,83,184,8,255,216,153,74,33,30,102,928,33,157,58,181,405,69,352,183,254,68,94,28,94,3,152,765,65,124,2,57,224,448,21,16,7,2,5,91,724,114,28,220,29,147,822,94,343,3,40,36,59,2,48,2,21,590,87,5,148,4,20,137,45,5,62,34,11,111,105,52,65,91,17,28,9,209,69,64,38,71,351,77,11,410,69,49,428,37,121,143,185,5,109,59,36,82,42,74,49,30,8,43,77,146,18,106,57,38,105,50,167,43,45,11,18,2,25,13,8,32,45,50,133,3,1,26,2,237,7,70,59,289,8,87,9,36,148,149,100,28,12,286,11,41,47,9,96,16,24,0,10,27,60,14,64,2,51,5,166,584,19,46,28,55,12,588,22,23,111,8,6,114,106,232,23,3,136,22,65,19,112,87],"type":"bar"},{"x":["coordinates","dynamically","prediction","posterior","processes","experiments","formula ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4536,), (4536, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.7413793103448276);'>segmentation</span> <span style=''>by</span> <span style=''>optimal</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>piecewise</span> <span style=''>constant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximations</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Piecewise</span> <span style=''>constant</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>number</span> <span style=''>of</span> <span style=''>segments</span> <span style=''>or</span> <span style=''>clusters</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disconnected</span> <span style=''>pixels</span> <span style=''>are</span> <span style=''>treated</span> <span style=''>The</span> <span style=''>method</span> <span style=''>of</span> <span style=''>majorizing</span> <span style=''>of</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>sequence</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximations</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style=''>case</span> <span style=''>of</span> <span style=''>color</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>multispectral</span> <span style=''>images</span> <span style=''>is</span> <span style=''>foreseen</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Mondrian</span> <span style=''>Kernel</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Mondrian</span> <span style=''>kernel</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>random</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Laplace</span> <span style=''>kernel</span> <span style=''>It</span> <span style=''>is</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>both</span> <span style=''>batch</span> <span style=''>and</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>kernel</span> <span style=''>width</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>as</span> <span style=''>the</span> <span style=''>random</span> <span style=''>features</span> <span style=''>can</span> <span style=''>be</span> <span style=''>re</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>for</span> <span style=''>all</span> <span style=''>kernel</span> <span style=''>widths</span> <span style=''>The</span> <span style=''>features</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>trees</span> <span style=''>via</span> <span style=''>a</span> <span style=''>Mondrian</span> <span style=''>process</span> <span style=''>Roy</span> <span style=''>and</span> <span style=''>Teh</span> <span style=''>2009</span> <span style=''>and</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlight</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>to</span> <span style=''>Mondrian</span> <span style=''>forests</span> <span style=''>Lakshminarayanan</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2014</span> <span style=''>where</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>also</span> <span style=''>sampled</span> <span style=''>via</span> <span style=''>a</span> <span style=''>Mondrian</span> <span style=''>process</span> <span style=''>but</span> <span style=''>fit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>This</span> <span style=''>link</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>new</span> <span style=''>insight</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>random</span> <span style=''>forests</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3397129186602871);'>dimension</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Deterministic</span> <span style=''>Approach</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contaminated</span> <span style=''>data</span> <span style=''>set</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.33931777378815076);'>dimensional</span> <span style=''>regime</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style=''>or</span> <span style=''>even</span> <span style=''>more</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43231441048034935);'>observations</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.33931777378815076);'>dimensional</span> <span style=''>robust</span> <span style=''>PCA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>inherits</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterpart</span> <span style=''>ie</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>robust</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contaminated</span> <span style=''>points</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>kernelizable</span> <span style='background-color:rgba(255, 0, 0, 0.6692913385826771);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>and</span> <span style=''>achieves</span> <span style=''>maximal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>breakdown</span> <span style=''>point</span> <span style=''>of</span> <span style=''>50</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importantly</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>exhibits</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.30038022813688214);'>efficiency</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.3) ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Communication</span> <span style=''>Limited</span> <span style=''>Systems</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>to</span> <span style=''>find</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>limited</span> <span style=''>systems</span> <span style=''>Aiming</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>(GPs)</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>systems</span> <span style=''>as</span> <span style=''>a</span> <span style=''>pivotal</span> <span style=''>example</span> <span style=''>We</span> <span style=''>first</span> <span style=''>address</span> <span style=''>a</span> <span style=''>very</span> <span style=''>basic</span> <span style=''>problem</span> <span style=''>how</span> <span style=''>many</span> <span style=''>bits</span> <span style=''>are</span> <span style=''>required</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>products</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>vectors</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>machines</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>bounds</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantization</span> <span style=''>Two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suboptimal</span> <span style=''>and</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>schemes</span> <span style=''>are</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substitute</span> <span style=''>for</span> <span style=''>the</span> <span style=''>vector</span> <span style='background ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.0900997150997151)
# 	architecture (0.08262108262108261)
# 	representation (0.12535612535612536)
# 	segmentation (0.07193732193732194)
# 	information (0.25783475783475784)
# 	experimental (0.14494301994301995)
# 	different (0.2724358974358974)
# 	detection (0.129985754985755)
# 	convolutional (0.12962962962962962)
# 	recognition (0.15242165242165243)
#
# Some Statistics words are:
# 	theoretical (0.14508032128514056)
# 	stochastic (0.13403614457831325)
# 	variables (0.14206827309236947)
# 	algorithm (0.3910642570281124)
# 	distribution (0.1897590361445783)
# 	estimation (0.17921686746987953)
# 	statistical (0.16616465863453816)
# 	dimensional (0.18724899598393574)
# 	inference (0.20080321285140562)
# 	regression (0.18875502008032127)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4f1d4b51-62cb-4c68-bc84-2627e859fe9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f1d4b51-62cb-4c68-bc84-2627e859fe9b")) {                    Plotly.newPlot(                        "4f1d4b51-62cb-4c68-bc84-2627e859fe9b",                        [{"x":["coordinates","dynamically","prediction","posterior","processes","experiments","formulation","structure","simulation","employing","tractable","automatically","flexibility","movements","collected","nonparametric","financial","illustrate","dimensional","characterizing","computational","inference","computation","relationship","relational","symmetric","continuous","performance","augmentation","theoretical","dimensionality","probability","efficient","dimension","representation","developed","application","representing","relations","processed","languages","displaced","statistical","different","mathematical","parameter","typologically","dependencies","distribution","applications","ontologies","constructs","ontological","terminating","expressiveness","constraint","information","reasoning","expressive","including","technologies","practical","algorithm","embedding","knowledge","presently","intuitive","extending","description","prominently","modelling","circumscription","developments","framework","semantics","defeasible","classifier","complementing","invariance","introduced","capabilities","uniformity","direction","occurrence","secondary","literature","simultaneously","descriptors","essential","advantages","perceptron","descriptor","invariants","benchmark","methodology","invariant","superiority","transform","techniques","relationships","collaboration","approaches","extracting","introducing","recognition","threshold","classifiers","empirical","efficiently","disjunction","convergence","minimization","generalizes","describes","intrinsic","advantage","optimizing","factorization","appealing","combinatorial","sequential","evaluated","illustrated","approximate","variational","parametric","approximation","assessment","probabilistic","deterministic","operators","strengths","alternatives","debugging","unstructured","facilitates","templates","partition","statistics","approximations","variables","phylogenetic","ensembling","averaging","explanatory","technique","continues","comparing","alignment","particular","categorical","generating","clusterings","demonstrating","clustering","conditions","sequences","suggested","dissimilarity","processing","analytically","considerable","restricted","simplified","computationally","intractable","intensive","asymptotics","posteriori","dirichlet","likelihood","ubiquitous","resources","plentiful","validation","degenerate","potential","algorithms","statistically","requiring","leverages","intelligent","interference","demonstrate","streaming","introduction","additional","surroundings","catastrophic","development","distributions","architecture","regularizer","everything","generative","continuously","incorporate","consecutive","components","reduction","circumvent","numerical","capability","simulated","operations","alternative","preserving","divergence","intractability","analytical","complexity","illumination","comparison","implement","refinements","effectiveness","correction","tremendous","challenges","respectively","particularly","implementation","transformation","demonstrates","variation","chromatic","outperforms","geometric","objective","furthermore","challenging","distortion","translated","specialised","implementing","translation","resulting","experimented","monolingual","attention","according","evaluation","directions","sentences","submitted","adaptation","visualizing","opportunity","neuroscientists","introduces","consonants","functional","multivariate","activities","classific ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	asymptotics
# 	intractability
# 	neuroscientists
# 	microarray
# 	eigenspace
# 	unbalancedness
# 	modulating
# 	integrator
# 	thermostat
# 	equitability
# 	prescribe
# 	stagewise
# 	reparameterizing
# 	psychiatric
# 	instabilities
# 	semiparametric
# 	infrequent
# 	decouples
# 	replicated
# 	inexactly
# Some words which never appear in Statistics papers:
# 	displaced
# 	typologically
# 	ontological
# 	terminating
# 	presently
# 	circumscription
# 	defeasible
# 	distinguishes
# 	strengthen
# 	syntactically
# 	combinational
# 	encouragingly
# 	compilation
# 	disjunctive
# 	propositional
# 	conversation
# 	referential
# 	psychologically
# 	radiomics
# 	polymorphism

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0659798871719406e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
